# %% [markdown]
# # Project Title : Covid's Effect on Real Estate
#
# Project Description : This project was created using jupyter notebook to perform an analysis over real estate pricing in Canada and to find a correlation between covid-19 pandemic and real estate trends.
#
# Data Sets-
# CREA Canadian Housing market stats
# COVID-19 Epeddemiology update Summary
#
# Dataset References-
# Canada, P. H. A. of. (2023, May 9). Covid-19 epidemiology update: Summary. Canada.ca. https://health-infobase.canada.ca/covid-19/
# (n.d.). Canadian Housing Market Stats. CREA. https://stats.crea.ca/en-CA/
#
# Reference used for graphs-
# Bar graph : https://stackoverflow.com/questions/22508590/enumerate-plots-in-matplotlib-figure

# %%
# %matplotlib inline

# %%
# Import Dependencies
import pandas as pd
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

# %%
# Importing and reading csv files
ontario_csv= Path("../Resources/ONTARIO.csv")
saskatoon_csv= Path("../Resources/SASKATOON.csv")
aggregrate_csv = Path("../Resources/AGGREGATE.csv")
bancroft_csv = Path("../Resources/BANCROFT_AND_AREA.csv")
barrie_csv = Path("../Resources/BARRIE_AND_DISTRICT.csv")
calgary_csv = Path("../Resources/CALGARY.csv")
cambridge_csv = Path("../Resources/CAMBRIDGE.csv")
chilliwack_csv = Path("../Resources/CHILLIWACK_AND_DISTRICT.csv")
edmonton_csv = Path("../Resources/EDMONTON.csv")
greater_vancouver_csv = Path("../Resources/GREATER_VANCOUVER.csv")
grey_bruce_owen_sound_csv = Path("../Resources/GREY_BRUCE_OWEN_SOUND.csv")
guelph_csv = Path("../Resources/GUELPH_AND_DISTRICT.csv")
hamilton_csv = Path("../Resources/HAMILTON_BURLINGTON.csv")
interior_bc_csv = Path("../Resources/INTERIOR_BC.csv")
lower_mainland_csv = Path("../Resources/LOWER_MAINLAND.csv")
newfoundland_csv = Path("../Resources/NEWFOUNDLAND_AND_LABRADOR.csv")
ontario_csv = Path("../Resources/ONTARIO.csv")
saskatchewan_csv = Path("../Resources/SASKATCHEWAN.csv")
saskatoon_csv = Path("../Resources/SASKATOON.csv")
vancouver_island_csv = Path("../Resources/VANCOUVER_ISLAND.csv")
victoria_csv = Path("../Resources/VICTORIA.csv")
winnipeg_csv = Path("../Resources/WINNIPEG.csv")


# reading csv files
aggregrate_df = pd.read_csv(aggregrate_csv)
bancroft_df = pd.read_csv(bancroft_csv)
barrie_df = pd.read_csv(barrie_csv)
calgary_df = pd.read_csv(calgary_csv)
cambridge_df = pd.read_csv(cambridge_csv)
chilliwack_df = pd.read_csv(chilliwack_csv)
edmonton_df = pd.read_csv(edmonton_csv)
greater_vancouver_df = pd.read_csv(greater_vancouver_csv)
grey_bruce_owen_sound_df = pd.read_csv(grey_bruce_owen_sound_csv)
guelph_df = pd.read_csv(guelph_csv)
hamilton_df = pd.read_csv(hamilton_csv)
interior_bc_df = pd.read_csv(interior_bc_csv)
lower_mainland_df = pd.read_csv(lower_mainland_csv)
newfoundland_df = pd.read_csv(newfoundland_csv)
ontario_df = pd.read_csv(ontario_csv)
saskatchewan_df = pd.read_csv(saskatchewan_csv)
saskatoon_df = pd.read_csv(saskatoon_csv)
vancouver_island_df = pd.read_csv(vancouver_island_csv)
victoria_df = pd.read_csv(victoria_csv)
winnipeg_df = pd.read_csv(winnipeg_csv)

# %%
# removing NA values from the dataset
ontario_df= ontario_df.dropna()
saskatoon_df=saskatoon_df.dropna()
aggregrate_df = aggregrate_df.dropna()
bancroft_df = bancroft_df.dropna()
barrie_df = barrie_df.dropna()
calgary_df = calgary_df.dropna()
cambridge_df = cambridge_df.dropna()
chilliwack_df = chilliwack_df.dropna()
edmonton_df = edmonton_df.dropna()
greater_vancouver_df = greater_vancouver_df.dropna()
grey_bruce_owen_sound_df = grey_bruce_owen_sound_df.dropna()
guelph_df = guelph_df.dropna()
hamilton_df = hamilton_df.dropna()
interior_bc_df = interior_bc_df.dropna()
lower_mainland_df = lower_mainland_df.dropna()
newfoundland_df = newfoundland_df.dropna()
saskatchewan_df = saskatchewan_df.dropna()
vancouver_island_df = vancouver_island_df.dropna()
victoria_df = victoria_df.dropna()
winnipeg_df = winnipeg_df.dropna()

# %%
# Testing
chilliwack_df
# Out:
#          Date  Composite_HPI_SA  Single_Family_HPI_SA  One_Storey_HPI_SA  \
# 0    Jan 2005             100.0                 100.0              100.0
# 1    Feb 2005             101.3                 101.4              102.0
# 2    Mar 2005             103.0                 103.5              105.2
# 3    Apr 2005             104.1                 104.6              106.7
# 4    May 2005             104.4                 104.9              106.7
# ..        ...               ...                   ...                ...
# 223  Aug 2023             360.0                 368.6              375.0
# 224  Sep 2023             365.0                 375.3              400.5
# 225  Oct 2023             360.1                 367.7              377.7
# 226  Nov 2023             349.1                 354.7              355.4
# 227  Dec 2023             359.6                 367.7              384.1
#
#      Two_Storey_HPI_SA  Townhouse_HPI_SA  Apartment_HPI_SA  \
# ...

# %%
# Cleaning the data using item assignment so that it can be grouped nicely
# ------------------------------------------
value = "Saskatchewan"
saskatoon_df["Geographical Location"] = value
# --------------------------------------------
# ------------------------------------------
val_ont = "Ontario"
ontario_df["Geographical Location"] = val_ont
# --------------------------------------------
# ------------------------------------------
val_aggr = "Aggregrate"
aggregrate_df["Geographical Location"] = val_aggr
# --------------------------------------------
# ------------------------------------------
val_bancroft = "Ontario"
bancroft_df["Geographical Location"] = val_bancroft
# --------------------------------------------
# ------------------------------------------
val_b = "Ontario"
barrie_df["Geographical Location"] = val_b
# --------------------------------------------
# ------------------------------------------
val_cal = "Alberta"
calgary_df["Geographical Location"] = val_cal
# --------------------------------------------
# ------------------------------------------
val_cam = "Ontario"
cambridge_df["Geographical Location"] = val_cam
# --------------------------------------------
# ------------------------------------------
val_c = "Vancouver"
chilliwack_df["Geographical Location"] = val_c
# --------------------------------------------
# ------------------------------------------
val_edm = "Alberta"
edmonton_df["Geographical Location"] = val_edm
# --------------------------------------------
# ------------------------------------------
val_van= "Vancouver"
greater_vancouver_df["Geographical Location"] = val_van
# --------------------------------------------
# ------------------------------------------
val_grey = "Ontario"
grey_bruce_owen_sound_df["Geographical Location"] = val_grey
# --------------------------------------------
# ------------------------------------------
val_guelph = "Ontario"
guelph_df["Geographical Location"] = val_guelph
# --------------------------------------------
# ------------------------------------------
val_hamil = "Ontario"
hamilton_df["Geographical Location"] = val_hamil
# --------------------------------------------
# ------------------------------------------
val_bc = "Vancouver"
interior_bc_df["Geographical Location"] = val_bc
# --------------------------------------------
# ------------------------------------------
val_lower = "Vancouver"
lower_mainland_df["Geographical Location"] = val_lower
# --------------------------------------------
# ------------------------------------------
val_new = "Newfoundland and Labrador"
newfoundland_df["Geographical Location"] = val_new
# --------------------------------------------
# ------------------------------------------
val_sask = "Saskatchewan"
saskatchewan_df["Geographical Location"] = val_sask
# --------------------------------------------
# ------------------------------------------
val_van = "Vancouver"
vancouver_island_df["Geographical Location"] = val_van
# --------------------------------------------
# ------------------------------------------
val_vic = "Vancouver"
victoria_df["Geographical Location"] = val_vic
# --------------------------------------------
# ------------------------------------------
val_winni = "Manitoba"
winnipeg_df["Geographical Location"] = val_winni
# --------------------------------------------

# %%
# Setting Geographical Loacation as index for all df

ontario_df.set_index("Geographical Location", inplace=True)
saskatoon_df.set_index("Geographical Location", inplace=True)
aggregrate_df.set_index("Geographical Location", inplace=True)
bancroft_df.set_index("Geographical Location", inplace=True)
barrie_df.set_index("Geographical Location", inplace=True)
calgary_df.set_index("Geographical Location", inplace=True)
cambridge_df.set_index("Geographical Location", inplace=True)
chilliwack_df.set_index("Geographical Location", inplace=True)
edmonton_df.set_index("Geographical Location", inplace=True)
greater_vancouver_df.set_index("Geographical Location", inplace=True)
grey_bruce_owen_sound_df.set_index("Geographical Location", inplace=True)
guelph_df.set_index("Geographical Location", inplace=True)
hamilton_df.set_index("Geographical Location", inplace=True)
interior_bc_df.set_index("Geographical Location", inplace=True)
lower_mainland_df.set_index("Geographical Location", inplace=True)
newfoundland_df.set_index("Geographical Location", inplace=True)
saskatchewan_df.set_index("Geographical Location", inplace=True)
vancouver_island_df.set_index("Geographical Location", inplace=True)
victoria_df.set_index("Geographical Location", inplace=True)
winnipeg_df.set_index("Geographical Location", inplace=True)

# %%
# combining all df to once dataframe
concat_df= pd.concat([ontario_df,saskatoon_df,aggregrate_df,
                      bancroft_df,barrie_df,calgary_df,cambridge_df,
                      chilliwack_df,edmonton_df,greater_vancouver_df,
                      grey_bruce_owen_sound_df, guelph_df,hamilton_df,
                      interior_bc_df,lower_mainland_df,newfoundland_df,
                      saskatchewan_df,vancouver_island_df,victoria_df,
                      winnipeg_df],axis=0)
concat_df
# Out:
#                            Date  Composite_HPI_SA  Single_Family_HPI_SA  \
# Geographical Location
# Ontario                Jan 2005             100.0                 100.0
# Ontario                Feb 2005             100.2                 100.2
# Ontario                Mar 2005             100.6                 100.6
# Ontario                Apr 2005             100.9                 100.9
# Ontario                May 2005             101.3                 101.3
# ...                         ...               ...                   ...
# Manitoba               Aug 2023             285.3                 296.3
# Manitoba               Sep 2023             285.7                 296.4
# Manitoba               Oct 2023             285.1                 295.0
# Manitoba               Nov 2023             282.4                 292.5
# Manitoba               Dec 2023             283.4                 292.8
#
#                        One_Storey_HPI_SA  Two_Storey_HPI_SA  Townhouse_HPI_SA  \
# ...

# %%
# checking datatypes
concat_df.columns
concat_df.dtypes
# Out:
# Date                           object
# Composite_HPI_SA              float64
# Single_Family_HPI_SA          float64
# One_Storey_HPI_SA             float64
# Two_Storey_HPI_SA             float64
# Townhouse_HPI_SA              float64
# Apartment_HPI_SA              float64
# Composite_Benchmark_SA        float64
# Single_Family_Benchmark_SA    float64
# One_Storey_Benchmark_SA       float64
# Two_Storey_Benchmark_SA       float64
# Townhouse_Benchmark_SA        float64
# Apartment_Benchmark_SA        float64
# dtype: object

# %%
# changing datatypes

concat_df[['Composite_HPI_SA', 'Single_Family_HPI_SA',
            'One_Storey_HPI_SA','Two_Storey_HPI_SA', 
            'Townhouse_HPI_SA', 'Apartment_HPI_SA','Composite_Benchmark_SA', 
            'Single_Family_Benchmark_SA','One_Storey_Benchmark_SA', 
            'Two_Storey_Benchmark_SA', 'Townhouse_Benchmark_SA', 
            'Apartment_Benchmark_SA']] = concat_df[['Composite_HPI_SA', 'Single_Family_HPI_SA', 
                                                    'One_Storey_HPI_SA','Two_Storey_HPI_SA',
                                                      'Townhouse_HPI_SA', 'Apartment_HPI_SA','Composite_Benchmark_SA', 
                                                      'Single_Family_Benchmark_SA','One_Storey_Benchmark_SA',
                                                        'Two_Storey_Benchmark_SA', 'Townhouse_Benchmark_SA', 
                                                        'Apartment_Benchmark_SA']].astype(float)

concat_df
# Out:
#                            Date  Composite_HPI_SA  Single_Family_HPI_SA  \
# Geographical Location
# Ontario                Jan 2005             100.0                 100.0
# Ontario                Feb 2005             100.2                 100.2
# Ontario                Mar 2005             100.6                 100.6
# Ontario                Apr 2005             100.9                 100.9
# Ontario                May 2005             101.3                 101.3
# ...                         ...               ...                   ...
# Manitoba               Aug 2023             285.3                 296.3
# Manitoba               Sep 2023             285.7                 296.4
# Manitoba               Oct 2023             285.1                 295.0
# Manitoba               Nov 2023             282.4                 292.5
# Manitoba               Dec 2023             283.4                 292.8
#
#                        One_Storey_HPI_SA  Two_Storey_HPI_SA  Townhouse_HPI_SA  \
# ...

# %%
# renaming columns 

concat_df= concat_df.rename(columns={"Composite_HPI_SA" : "Composite HPI",
                                      "Single_Family_HPI_SA" : "Single Family HPI",
                                      "One_Storey_HPI_SA" : "One Storey HPI",
                                      "Two_Storey_HPI_SA" : "Two Storey HPI",
                                      "Townhouse_HPI_SA" : "Townhouse HPI",
                                      "Apartment_HPI_SA": "Apartment HPI",
                                      "Composite_Benchmark_SA" : "Composite House",
                                      "Single_Family_Benchmark_SA" : "Single Family House",
                                      "One_Storey_Benchmark_SA" : "One Storey House",
                                      "Two_Storey_Benchmark_SA" : "Two Storey House",
                                      "Townhouse_Benchmark_SA" : "Townhouse House",
                                      "Apartment_Benchmark_SA": "Apartment House",})

# %%
# checking datatypes
concat_df.dtypes
# Out:
# Date                    object
# Composite HPI          float64
# Single Family HPI      float64
# One Storey HPI         float64
# Two Storey HPI         float64
# Townhouse HPI          float64
# Apartment HPI          float64
# Composite House        float64
# Single Family House    float64
# One Storey House       float64
# Two Storey House       float64
# Townhouse House        float64
# Apartment House        float64
# dtype: object

# %%
#Resetting index 
concat_df=concat_df.reset_index()

# %%
#renaming column to Provience
concat_df= concat_df.rename(columns={"Geographical Location": "Provience"})
concat_df
# Out:
#      Provience      Date  Composite HPI  Single Family HPI  One Storey HPI  \
# 0      Ontario  Jan 2005          100.0              100.0           100.0
# 1      Ontario  Feb 2005          100.2              100.2           100.2
# 2      Ontario  Mar 2005          100.6              100.6           100.3
# 3      Ontario  Apr 2005          100.9              100.9           100.7
# 4      Ontario  May 2005          101.3              101.3           100.9
# ...        ...       ...            ...                ...             ...
# 4555  Manitoba  Aug 2023          285.3              296.3           286.1
# 4556  Manitoba  Sep 2023          285.7              296.4           285.3
# 4557  Manitoba  Oct 2023          285.1              295.0           285.1
# 4558  Manitoba  Nov 2023          282.4              292.5           283.1
# 4559  Manitoba  Dec 2023          283.4              292.8           281.6
#
# ...

# %%
# exporting cleaned csv to Output 
concat_df.to_csv("../Output- Cleaned Datasets/real_estate_clean.csv",
                  encoding="utf-8", index=False, header=True)

# %%
# checking Date type and format
concat_df["Date"]
# Out:
# 0       Jan 2005
# 1       Feb 2005
# 2       Mar 2005
# 3       Apr 2005
# 4       May 2005
#           ...
# 4555    Aug 2023
# 4556    Sep 2023
# 4557    Oct 2023
# 4558    Nov 2023
# 4559    Dec 2023
# Name: Date, Length: 4560, dtype: object

# %%
# Extracting year from Date
concat_df[["Month","Year"]]= concat_df["Date"].str.split(" ",expand=True)
concat_df.head()
# Out:
#   Provience      Date  Composite HPI  Single Family HPI  One Storey HPI  \
# 0   Ontario  Jan 2005          100.0              100.0           100.0
# 1   Ontario  Feb 2005          100.2              100.2           100.2
# 2   Ontario  Mar 2005          100.6              100.6           100.3
# 3   Ontario  Apr 2005          100.9              100.9           100.7
# 4   Ontario  May 2005          101.3              101.3           100.9
#
#    Two Storey HPI  Townhouse HPI  Apartment HPI  Composite House  \
# 0           100.0          100.0          100.0         265700.0
# 1           100.2          100.0          100.3         266300.0
# 2           100.6          100.3          101.0         267300.0
# 3           100.9          100.4          101.2         268000.0
# 4           101.3          100.7          102.1         269100.0
#
#    Single Family House  One Storey House  Two Storey House  Townhouse House  \
# ...

# %%
# changing dtypes as after exporting the file dtypes change for df 
concat_df[['Composite HPI', 'Single Family HPI',
            'One Storey HPI','Two Storey HPI', 
            'Townhouse HPI', 'Apartment HPI','Composite House', 
            'Single Family House','One Storey House', 
            'Two Storey House', 'Townhouse House', 
            'Apartment House']] = concat_df[['Composite HPI', 'Single Family HPI', 
                                                    'One Storey HPI','Two Storey HPI',
                                                      'Townhouse HPI', 'Apartment HPI','Composite House', 
                                                      'Single Family House','One Storey House',
                                                        'Two Storey House', 'Townhouse House', 
                                                        'Apartment House']].astype(float)

concat_df
# Out:
#      Provience      Date  Composite HPI  Single Family HPI  One Storey HPI  \
# 0      Ontario  Jan 2005          100.0              100.0           100.0
# 1      Ontario  Feb 2005          100.2              100.2           100.2
# 2      Ontario  Mar 2005          100.6              100.6           100.3
# 3      Ontario  Apr 2005          100.9              100.9           100.7
# 4      Ontario  May 2005          101.3              101.3           100.9
# ...        ...       ...            ...                ...             ...
# 4555  Manitoba  Aug 2023          285.3              296.3           286.1
# 4556  Manitoba  Sep 2023          285.7              296.4           285.3
# 4557  Manitoba  Oct 2023          285.1              295.0           285.1
# 4558  Manitoba  Nov 2023          282.4              292.5           283.1
# 4559  Manitoba  Dec 2023          283.4              292.8           281.6
#
# ...

# %%
# using group by function to find average price for each home type by provience and year
real_estate_final_df= concat_df.groupby(["Year","Provience"])
real_estate_by_year_df= pd.DataFrame(real_estate_final_df[['Composite HPI', 'Single Family HPI',
                                                        'One Storey HPI','Two Storey HPI', 
                                                        'Townhouse HPI', 'Apartment HPI','Composite House', 
                                                        'Single Family House','One Storey House', 
                                                        'Two Storey House', 'Townhouse House', 
                                                        'Apartment House']].median())

real_estate_by_year_df
# Out:
#                                 Composite HPI  Single Family HPI  \
# Year Provience
# 2005 Aggregrate                        102.25             102.05
#      Alberta                           100.45             100.30
#      Manitoba                          104.30             104.35
#      Newfoundland and Labrador         103.00             103.00
#      Ontario                           101.30             101.40
# ...                                       ...                ...
# 2023 Manitoba                          281.95             292.40
#      Newfoundland and Labrador         217.70             218.90
#      Ontario                           355.05             364.15
#      Saskatchewan                      289.00             305.05
#      Vancouver                         331.70             346.45
#
#                                 One Storey HPI  Two Storey HPI  Townhouse HPI  \
# Year Provience
# ...

# %%
# Creating a visulasation
real_estate_by_year_df.reset_index(inplace=True)
real_estate_by_year_df["Year"] = real_estate_by_year_df["Year"].astype(int)

# Filter the data for years 2016 to 2023
filtered_df = real_estate_by_year_df[(real_estate_by_year_df["Year"] >= 2016) & (real_estate_by_year_df["Year"] <= 2023)]

plt.figure(figsize=(12, 6))
x = filtered_df["Year"]
house_types = ["Composite House", "Single Family House", "One Storey House", "Two Storey House", "Townhouse House", "Apartment House"]
colors = ['blue', 'orange', 'green', 'red', 'purple', 'brown']

# Plotting the bars for each house type
for i, house_type in enumerate(house_types):
    plt.bar(x + i * 0.1, filtered_df[house_type], width=0.1, label=house_type, color=colors[i])

# Adding titles and labels
plt.title('Average Real Estate Prices by Year (2016-2023)')
plt.xlabel('Year')
plt.ylabel('Housing Price')

# Setting x-axis ticks and labels with rotation
plt.xticks(x, rotation=0)

plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.savefig('Average Real Estate Price By Year.png')
plt.show()

# %% [markdown]
# - The above finding shows a gradual increase in Real Estate market average value for each housing types from 2016 to 2019.
# - However, from 2020 to 2022 there was a significant increase in the average home price for each housing type.
# - For composite housing type the percentage increase from 2020 to 2021 was roughly 19 % , followed by 10 % increase from 2021 to 2022 and a decrease of 5.2 % was noticed from 2022 to 2023.

# %%
covid19_csv= Path("../Output- Cleaned Datasets/covid19_df.csv")
covid19_df = pd.read_csv(covid19_csv)
covid19_df.head()
# Out:
#    reporting_year  Province_ID          Province       Province_French  \
# 0            2020           59  British Columbia  Colombie-Britannique
# 1            2020           48           Alberta               Alberta
# 2            2020           47      Saskatchewan          Saskatchewan
# 3            2020           46          Manitoba              Manitoba
# 4            2020           35           Ontario               Ontario
#
#          date  reporting_week  update  totalcases  numtotal_last7  \
# 0  2020-02-01               5     1.0           1             1.0
# 1  2020-02-01               5     1.0           0             0.0
# 2  2020-02-01               5     1.0           0             0.0
# 3  2020-02-01               5     1.0           0             0.0
# 4  2020-02-01               5     1.0           3             0.0
#
#    ratecases_total  ...  numdeaths_last14 ratetotal_last14  ratedeaths_last14  \
# ...

# %%
covid19_df = covid19_df.rename(columns={"reporting_year": "Year",
                                         "Province" : "Provience" ,
                                           "totalcases" : "Total cases"})
covid19_df
# Out:
#       Year  Province_ID               Provience            Province_French  \
# 0     2020           59        British Columbia       Colombie-Britannique
# 1     2020           48                 Alberta                    Alberta
# 2     2020           47            Saskatchewan               Saskatchewan
# 3     2020           46                Manitoba                   Manitoba
# 4     2020           35                 Ontario                    Ontario
# ...    ...          ...                     ...                        ...
# 3130  2024           60                   Yukon                      Yukon
# 3131  2024           61   Northwest Territories  Territoires du Nord-Ouest
# 3132  2024           62                 Nunavut                    Nunavut
# 3133  2024           99  Repatriated travellers        Voyageurs rapatriés
# 3134  2024            1                  Canada                     Canada
#
# ...

# %%
covid19_df= pd.DataFrame(covid19_df[["Year","Provience","Total cases"]])
covid19_df
# Out:
#       Year               Provience  Total cases
# 0     2020        British Columbia            1
# 1     2020                 Alberta            0
# 2     2020            Saskatchewan            0
# 3     2020                Manitoba            0
# 4     2020                 Ontario            3
# ...    ...                     ...          ...
# 3130  2024                   Yukon         4989
# 3131  2024   Northwest Territories        11511
# 3132  2024                 Nunavut         3531
# 3133  2024  Repatriated travellers           13
# 3134  2024                  Canada      4921299
#
# [3135 rows x 3 columns]

# %%
covid19_df= covid19_df.groupby(["Year","Provience"])
covid19_df= pd.DataFrame(covid19_df["Total cases"].sum())
covid19_df
# Out:
#                              Total cases
# Year Provience
# 2020 Alberta                      964330
#      British Columbia             477505
#      Canada                      7105487
#      Manitoba                     190514
#      New Brunswick                 10018
# ...                                  ...
# 2024 Prince Edward Island         233216
#      Quebec                      5775023
#      Repatriated travellers           52
#      Saskatchewan                 648819
#      Yukon                         19956
#
# [75 rows x 1 columns]

# %%
real_estate_by_year_df.set_index(['Year', 'Provience'], inplace=True)

# %%
# Now, both DataFrames have the same index names ('Year' and 'Province'), and you can proceed with the merge operation
covid_realestate_2020_2023 = pd.merge(real_estate_by_year_df, covid19_df, left_index=True, right_index=True)

# %%
covid_realestate_2020_2023
# Out:
#                                 Composite HPI  Single Family HPI  \
# Year Provience
# 2020 Alberta                           193.90             192.45
#      Manitoba                          239.65             245.55
#      Newfoundland and Labrador         179.00             179.50
#      Ontario                           253.15             255.00
#      Saskatchewan                      249.60             263.45
# 2021 Alberta                           210.15             209.20
#      Manitoba                          272.00             280.60
#      Newfoundland and Labrador         194.70             195.60
#      Ontario                           344.75             351.70
#      Saskatchewan                      272.50             288.85
# 2022 Alberta                           230.15             227.35
#      Manitoba                          289.90             299.50
#      Newfoundland and Labrador         213.60             214.70
# ...

# %%
covid_realestate_2020_2023.describe()
# Out:
#        Composite HPI  Single Family HPI  One Storey HPI  Two Storey HPI  \
# count      20.000000          20.000000       20.000000       20.000000
# mean      259.085000         265.210000      262.372500      261.017500
# std        55.253243          58.913388       56.164241       60.242639
# min       179.000000         179.500000      186.700000      178.300000
# 25%       216.675000         217.850000      221.250000      211.500000
# 50%       251.375000         259.225000      258.800000      255.750000
# 75%       287.237500         300.412500      289.862500      297.862500
# max       380.300000         385.800000      383.600000      383.800000
#
#        Townhouse HPI  Apartment HPI  Composite House  Single Family House  \
# count      20.000000      20.000000        20.000000            20.000000
# mean      253.817500     222.260000    417255.000000        448110.000000
# std        71.215154      53.291674    182265.726995        201095.447094
# ...

# %%
covid19_df.reset_index()
# Out:
#     Year               Provience  Total cases
# 0   2020                 Alberta       964330
# 1   2020        British Columbia       477505
# 2   2020                  Canada      7105487
# 3   2020                Manitoba       190514
# 4   2020           New Brunswick        10018
# ..   ...                     ...          ...
# 70  2024    Prince Edward Island       233216
# 71  2024                  Quebec      5775023
# 72  2024  Repatriated travellers           52
# 73  2024            Saskatchewan       648819
# 74  2024                   Yukon        19956
#
# [75 rows x 3 columns]

# %%
covid19_df.max()
# Out:
# Total cases    244473847
# dtype: int64

# %%
covid_cases_per_province_year = covid19_df.pivot_table(index='Year', columns='Provience', values='Total cases', aggfunc='sum')

# Plotting bar graphs for each province
for province in covid_cases_per_province_year.columns:
    plt.figure(figsize=(5, 4))
    plt.bar(covid_cases_per_province_year.index, covid_cases_per_province_year[province], width=0.5)
    plt.title(f'COVID-19 Cases in {province} per Year')
    plt.xlabel('Year')
    plt.ylabel('Total COVID-19 Cases')
    plt.xticks(covid_cases_per_province_year.index)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    # plt.savefig('Output/Covid-19 Cases in Each Provience per Year.png')
    plt.show()

# %% [markdown]
# The above findings shows COVID-19 cases in each provience over years ( 2020 - 2024) .
# - The higest covid cases were noticed in Ontario at 18,849,3950 followed by Quebec at 15,499,9135  followed by Alberta at 7,855,1765.
# - The lowest COVID cases were noticed in Nunavut at 39,7217 followed by Yukon at 53,2563

# %%
covid_realestate_2020_2023.reset_index(inplace=True)
covid_realestate_2020_2023
# Out:
#     Year                  Provience  Composite HPI  Single Family HPI  \
# 0   2020                    Alberta         193.90             192.45
# 1   2020                   Manitoba         239.65             245.55
# 2   2020  Newfoundland and Labrador         179.00             179.50
# 3   2020                    Ontario         253.15             255.00
# 4   2020               Saskatchewan         249.60             263.45
# 5   2021                    Alberta         210.15             209.20
# 6   2021                   Manitoba         272.00             280.60
# 7   2021  Newfoundland and Labrador         194.70             195.60
# 8   2021                    Ontario         344.75             351.70
# 9   2021               Saskatchewan         272.50             288.85
# 10  2022                    Alberta         230.15             227.35
# 11  2022                   Manitoba         289.90             299.50
# ...

# %%
print(covid_realestate_2020_2023.columns)
# Out:
# Index(['Year', 'Provience', 'Composite HPI', 'Single Family HPI',
#        'One Storey HPI', 'Two Storey HPI', 'Townhouse HPI', 'Apartment HPI',
#        'Composite House', 'Single Family House', 'One Storey House',
#        'Two Storey House', 'Townhouse House', 'Apartment House',
#        'Total cases'],
#       dtype='object')

# %%
for province in covid_realestate_2020_2023['Provience'].unique():
    # Filter data for the current province
    province_data = covid_realestate_2020_2023[covid_realestate_2020_2023['Provience'] == province]
    
    # Plot the line graph
    plt.figure(figsize=(10, 6))
    plt.plot(province_data['Year'], province_data['Composite HPI'], label='Composite HPI')
    plt.plot(province_data['Year'], province_data['Single Family HPI'], label='Single Family HPI')
    plt.plot(province_data['Year'], province_data['One Storey HPI'], label='One Storey HPI')
    plt.plot(province_data['Year'], province_data['Two Storey HPI'], label='Two Storey HPI')
    plt.plot(province_data['Year'], province_data['Townhouse HPI'], label='Townhouse HPI')
    plt.plot(province_data['Year'], province_data['Apartment HPI'], label='Apartment HPI')
    plt.title(f'Housing Price Index Increase in {province}')
    plt.xlabel('Year')
    plt.ylabel('Housing Price Index')
    plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
    plt.grid(True)
    # plt.savefig('Output/Housing Price Increase in Each Provience.png')
    plt.show()

# %% [markdown]
# The above figures shows the increase of HPI( Housing price index ) throughout 2020 to 2023. The average higest increase was noticed in 2022 with all the proviences. Ontario and Manitoba had the higest increase in HPI in 2022 follwed by a gradual decrease. However, proviences such as Newfoundland and Saskatwan had a drastic increase from  2020 to 2022 , follwed by a steady increase from 2022 to 2023.

# %%
# Iterate over each province
for province in covid_realestate_2020_2023['Provience'].unique():
    # Filter data for the current province
    province_data = covid_realestate_2020_2023[covid_realestate_2020_2023['Provience'] == province]
    
    # Plot the scatter plot
    plt.figure(figsize=(8,5))
    plt.scatter(province_data['Total cases'], province_data['Composite HPI'], label='Composite HPI')
    plt.scatter(province_data['Total cases'], province_data['Single Family HPI'], label='Single Family HPI')
    plt.scatter(province_data['Total cases'], province_data['One Storey HPI'], label='One Storey HPI')
    plt.scatter(province_data['Total cases'], province_data['Two Storey HPI'], label='Two Storey HPI')
    plt.scatter(province_data['Total cases'], province_data['Townhouse HPI'], label='Townhouse HPI')
    plt.scatter(province_data['Total cases'], province_data['Apartment HPI'], label='Apartment HPI')
    plt.title(f'Correlation between COVID Cases and House Prices in {province}')
    plt.xlabel('Total COVID Cases')
    plt.ylabel('Housing Price Index')
    plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
    plt.grid(True)
    # plt.savefig('Output/Correlation between COVID Cases and House Prices per Provience.png')
    plt.show()

# %% [markdown]
# The above scatterplot figers shows a correlation between covid-19 cases and HPI( Housing Price Index) , the legder shows the housing type. In the findings it is clear that with increase in COVID-19 cases there was a noticable increase in HPI. The higest HPI was noticed in Ontario at approx 430 , followed by Manitoba at 315 and Saskatwaen at 310.
