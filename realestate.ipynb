# %%
# Import Dependencies
import pandas as pd
from pathlib import Path

# %%
ontario_csv= Path("Resources/ONTARIO.csv")
saskatoon_csv= Path("Resources/SASKATOON.csv")
ontario_df= pd.read_csv(ontario_csv)
saskatoon_df= pd.read_csv(saskatoon_csv)
ontario_df
# Out:
#          Date  Composite_HPI_SA  Single_Family_HPI_SA  One_Storey_HPI_SA  \
# 0    Jan 2005             100.0                 100.0              100.0
# 1    Feb 2005             100.2                 100.2              100.2
# 2    Mar 2005             100.6                 100.6              100.3
# 3    Apr 2005             100.9                 100.9              100.7
# 4    May 2005             101.3                 101.3              100.9
# ..        ...               ...                   ...                ...
# 494       NaN               NaN                   NaN                NaN
# 495       NaN               NaN                   NaN                NaN
# 496       NaN               NaN                   NaN                NaN
# 497       NaN               NaN                   NaN                NaN
# 498       NaN               NaN                   NaN                NaN
#
#      Two_Storey_HPI_SA  Townhouse_HPI_SA  Apartment_HPI_SA  \
# ...

# %%
ontario_df.dropna()
saskatoon_df.dropna()
# Out:
#          Date  Composite_HPI_SA  Single_Family_HPI_SA  One_Storey_HPI_SA  \
# 0    Jan 2005             100.0                 100.0              100.0
# 1    Feb 2005             100.8                 101.0              102.3
# 2    Mar 2005             100.0                 100.2              102.0
# 3    Apr 2005             101.2                 101.6              103.7
# 4    May 2005             102.6                 103.2              105.1
# ..        ...               ...                   ...                ...
# 223  Aug 2023             289.7                 313.0              307.0
# 224  Sep 2023             293.9                 318.4              311.3
# 225  Oct 2023             295.9                 320.6              312.4
# 226  Nov 2023             296.5                 320.8              314.9
# 227  Dec 2023             294.1                 317.9              311.2
#
#      Two_Storey_HPI_SA  Townhouse_HPI_SA  Apartment_HPI_SA  \
# ...

# %%
# ontario_df = ontario_df[["Composite_HPI_SA" , "Date"]]
ontario_df = ontario_df.dropna()
ontario_df
# Out:
#          Date  Composite_HPI_SA  Single_Family_HPI_SA  One_Storey_HPI_SA  \
# 0    Jan 2005             100.0                 100.0              100.0
# 1    Feb 2005             100.2                 100.2              100.2
# 2    Mar 2005             100.6                 100.6              100.3
# 3    Apr 2005             100.9                 100.9              100.7
# 4    May 2005             101.3                 101.3              100.9
# ..        ...               ...                   ...                ...
# 223  Aug 2023             345.6                 350.3              341.2
# 224  Sep 2023             342.7                 346.6              339.7
# 225  Oct 2023             337.9                 341.5              334.4
# 226  Nov 2023             332.7                 335.9              329.1
# 227  Dec 2023             329.0                 331.7              323.4
#
#      Two_Storey_HPI_SA  Townhouse_HPI_SA  Apartment_HPI_SA  \
# ...

# %%
# ontario_df = ontario_df.groupby("Date").mean()
# saskatoon_df= saskatoon_df.groupby("Date").mean()
# saskatoon_df

# %%
value = "Saskatoon"
saskatoon_df["Provience"] = value
saskatoon_df
# Out:
#          Date  Composite_HPI_SA  Single_Family_HPI_SA  One_Storey_HPI_SA  \
# 0    Jan 2005             100.0                 100.0              100.0
# 1    Feb 2005             100.8                 101.0              102.3
# 2    Mar 2005             100.0                 100.2              102.0
# 3    Apr 2005             101.2                 101.6              103.7
# 4    May 2005             102.6                 103.2              105.1
# ..        ...               ...                   ...                ...
# 494       NaN               NaN                   NaN                NaN
# 495       NaN               NaN                   NaN                NaN
# 496       NaN               NaN                   NaN                NaN
# 497       NaN               NaN                   NaN                NaN
# 498       NaN               NaN                   NaN                NaN
#
#      Two_Storey_HPI_SA  Townhouse_HPI_SA  Apartment_HPI_SA  \
# ...

# %%
value_a = "Ontario"
ontario_df["Provience"] = value_a
ontario_df
# Out:
# C:\Users\jasle\AppData\Local\Temp\ipykernel_31808\2673663469.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ontario_df["Provience"] = value_a
#          Date  Composite_HPI_SA  Single_Family_HPI_SA  One_Storey_HPI_SA  \
# 0    Jan 2005             100.0                 100.0              100.0
# 1    Feb 2005             100.2                 100.2              100.2
# 2    Mar 2005             100.6                 100.6              100.3
# 3    Apr 2005             100.9                 100.9              100.7
# 4    May 2005             101.3                 101.3              100.9
# ..        ...               ...                   ...                ...
# ...

# %%
ontario_df.set_index("Provience", inplace=True)
ontario_df
# Out:
#                Date  Composite_HPI_SA  Single_Family_HPI_SA  \
# Provience
# Ontario    Jan 2005             100.0                 100.0
# Ontario    Feb 2005             100.2                 100.2
# Ontario    Mar 2005             100.6                 100.6
# Ontario    Apr 2005             100.9                 100.9
# Ontario    May 2005             101.3                 101.3
# ...             ...               ...                   ...
# Ontario    Aug 2023             345.6                 350.3
# Ontario    Sep 2023             342.7                 346.6
# Ontario    Oct 2023             337.9                 341.5
# Ontario    Nov 2023             332.7                 335.9
# Ontario    Dec 2023             329.0                 331.7
#
#            One_Storey_HPI_SA  Two_Storey_HPI_SA  Townhouse_HPI_SA  \
# Provience
# Ontario                100.0              100.0             100.0
# Ontario                100.2              100.2             100.0
# ...

# %%
saskatoon_df.set_index("Provience", inplace=True)
saskatoon_df=saskatoon_df.dropna()
saskatoon_df
# Out:
#                Date  Composite_HPI_SA  Single_Family_HPI_SA  \
# Provience
# Saskatoon  Jan 2005             100.0                 100.0
# Saskatoon  Feb 2005             100.8                 101.0
# Saskatoon  Mar 2005             100.0                 100.2
# Saskatoon  Apr 2005             101.2                 101.6
# Saskatoon  May 2005             102.6                 103.2
# ...             ...               ...                   ...
# Saskatoon  Aug 2023             289.7                 313.0
# Saskatoon  Sep 2023             293.9                 318.4
# Saskatoon  Oct 2023             295.9                 320.6
# Saskatoon  Nov 2023             296.5                 320.8
# Saskatoon  Dec 2023             294.1                 317.9
#
#            One_Storey_HPI_SA  Two_Storey_HPI_SA  Townhouse_HPI_SA  \
# Provience
# Saskatoon              100.0              100.0             100.0
# Saskatoon              102.3               99.6             100.6
# ...

# %%
concat_df= pd.concat([ontario_df,saskatoon_df],axis=0)
concat_df
# Out:
#                Date  Composite_HPI_SA  Single_Family_HPI_SA  \
# Provience
# Ontario    Jan 2005             100.0                 100.0
# Ontario    Feb 2005             100.2                 100.2
# Ontario    Mar 2005             100.6                 100.6
# Ontario    Apr 2005             100.9                 100.9
# Ontario    May 2005             101.3                 101.3
# ...             ...               ...                   ...
# Saskatoon  Aug 2023             289.7                 313.0
# Saskatoon  Sep 2023             293.9                 318.4
# Saskatoon  Oct 2023             295.9                 320.6
# Saskatoon  Nov 2023             296.5                 320.8
# Saskatoon  Dec 2023             294.1                 317.9
#
#            One_Storey_HPI_SA  Two_Storey_HPI_SA  Townhouse_HPI_SA  \
# Provience
# Ontario                100.0              100.0             100.0
# Ontario                100.2              100.2             100.0
# ...

# %%
concat_df.columns
concat_df.dtypes
# Out:
# Date                           object
# Composite_HPI_SA               object
# Single_Family_HPI_SA           object
# One_Storey_HPI_SA             float64
# Two_Storey_HPI_SA             float64
# Townhouse_HPI_SA              float64
# Apartment_HPI_SA              float64
# Composite_Benchmark_SA        float64
# Single_Family_Benchmark_SA    float64
# One_Storey_Benchmark_SA       float64
# Two_Storey_Benchmark_SA       float64
# Townhouse_Benchmark_SA        float64
# Apartment_Benchmark_SA        float64
# dtype: object

# %%
# # data formatting
# Index(['Date', 'Composite_HPI_SA', 'Single_Family_HPI_SA', 'One_Storey_HPI_SA',
#        'Two_Storey_HPI_SA', 'Townhouse_HPI_SA', 'Apartment_HPI_SA',
#        'Composite_Benchmark_SA', 'Single_Family_Benchmark_SA',
#        'One_Storey_Benchmark_SA', 'Two_Storey_Benchmark_SA',
#        'Townhouse_Benchmark_SA', 'Apartment_Benchmark_SA'],
#       dtype='object')

concat_df["Single_Family_HPI_SA"] = concat_df["Single_Family_HPI_SA"].astype(float).map("${:,.2f}".format)
concat_df
# Out:
#                Date  Composite_HPI_SA Single_Family_HPI_SA  One_Storey_HPI_SA  \
# Provience
# Ontario    Jan 2005             100.0              $100.00              100.0
# Ontario    Feb 2005             100.2              $100.20              100.2
# Ontario    Mar 2005             100.6              $100.60              100.3
# Ontario    Apr 2005             100.9              $100.90              100.7
# Ontario    May 2005             101.3              $101.30              100.9
# ...             ...               ...                  ...                ...
# Saskatoon  Aug 2023             289.7              $313.00              307.0
# Saskatoon  Sep 2023             293.9              $318.40              311.3
# Saskatoon  Oct 2023             295.9              $320.60              312.4
# Saskatoon  Nov 2023             296.5              $320.80              314.9
# Saskatoon  Dec 2023             294.1              $317.90              311.2
#
# ...
