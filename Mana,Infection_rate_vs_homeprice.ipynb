# %% [markdown]
# Infection Covid 19 rate vs. Home prices
#
# Question:
# How did Covid-19 affect Home Prices
#
# Methods to determine outcome:
# Create multi plot graphs to compare changes in 2 selected
#
# Create line graph to represent the changes in Covid-19 cases over time (2020-2023)
#
# Create scatterplots to visualize the comparison of Covid-19 cases to the 2 selected Mortgage rates.
# #test

# %%
#Import Dependancies
import pandas as pd
import pathlib as path
import matplotlib.pyplot as plt
import numpy as np

# %%
#Case Stud_
Real_estate_path= "Output/real_estate_clean.csv"
covid_case_path = "covid19_df.csv"

# %%
#Read the CSV Files
Real_estate_df = pd.read_csv(Real_estate_path)
covid_case_df= pd.read_csv(covid_case_path)

# %%
#Diplay first dataframe
Real_estate_df
# Out:
#      Geographical Location      Date  Composite HPI  Single Family HPI  \
# 0                  Ontario  Jan 2005          100.0              100.0
# 1                  Ontario  Feb 2005          100.2              100.2
# 2                  Ontario  Mar 2005          100.6              100.6
# 3                  Ontario  Apr 2005          100.9              100.9
# 4                  Ontario  May 2005          101.3              101.3
# ...                    ...       ...            ...                ...
# 4555              Manitoba  Aug 2023          285.3              296.3
# 4556              Manitoba  Sep 2023          285.7              296.4
# 4557              Manitoba  Oct 2023          285.1              295.0
# 4558              Manitoba  Nov 2023          282.4              292.5
# 4559              Manitoba  Dec 2023          283.4              292.8
#
#       One Storey HPI  Two Storey HPI  Townhouse HPI  Apartment HPI  \
# ...

# %%
Real_estate_df.dtypes
# Out:
# Geographical Location     object
# Date                      object
# Composite HPI            float64
# Single Family HPI        float64
# One Storey HPI           float64
# Two Storey HPI           float64
# Townhouse HPI            float64
# Apartment HPI            float64
# Composite House          float64
# Single Family House      float64
# One Storey House         float64
# Two Storey House         float64
# Townhouse House          float64
# Apartment House          float64
# dtype: object

# %%
# Convert the 'date' column to string data type
Real_estate_df['Date'] = Real_estate_df['Date'].astype(str)

# Extract the year component and store it in a new column named 'year'
Real_estate_df['year'] = pd.to_datetime(Real_estate_df['Date']).dt.year

# Convert the 'year' column from float to integer
Real_estate_df['year'] = Real_estate_df['year'].astype(int)

# Now, 'year' column contains integer values representing the years
print(Real_estate_df)
# Out:
#      Geographical Location      Date  Composite HPI  Single Family HPI  \
# 0                  Ontario  Jan 2005          100.0              100.0
# 1                  Ontario  Feb 2005          100.2              100.2
# 2                  Ontario  Mar 2005          100.6              100.6
# 3                  Ontario  Apr 2005          100.9              100.9
# 4                  Ontario  May 2005          101.3              101.3
# ...                    ...       ...            ...                ...
# 4555              Manitoba  Aug 2023          285.3              296.3
# 4556              Manitoba  Sep 2023          285.7              296.4
# 4557              Manitoba  Oct 2023          285.1              295.0
# 4558              Manitoba  Nov 2023          282.4              292.5
# 4559              Manitoba  Dec 2023          283.4              292.8
#
#       One Storey HPI  Two Storey HPI  Townhouse HPI  Apartment HPI  \
# ...

# %%
# Now, 'year' column contains integer values representing the years
Real_estate_df
# Out:
#      Geographical Location      Date  Composite HPI  Single Family HPI  \
# 0                  Ontario  Jan 2005          100.0              100.0
# 1                  Ontario  Feb 2005          100.2              100.2
# 2                  Ontario  Mar 2005          100.6              100.6
# 3                  Ontario  Apr 2005          100.9              100.9
# 4                  Ontario  May 2005          101.3              101.3
# ...                    ...       ...            ...                ...
# 4555              Manitoba  Aug 2023          285.3              296.3
# 4556              Manitoba  Sep 2023          285.7              296.4
# 4557              Manitoba  Oct 2023          285.1              295.0
# 4558              Manitoba  Nov 2023          282.4              292.5
# 4559              Manitoba  Dec 2023          283.4              292.8
#
#       One Storey HPI  Two Storey HPI  Townhouse HPI  Apartment HPI  \
# ...

# %%
Real_estate_df= Real_estate_df.rename(columns={"Geographical Location": "Province","year":"Year"})
Real_estate_df
# Out:
#       Province      Date  Composite HPI  Single Family HPI  One Storey HPI  \
# 0      Ontario  Jan 2005          100.0              100.0           100.0
# 1      Ontario  Feb 2005          100.2              100.2           100.2
# 2      Ontario  Mar 2005          100.6              100.6           100.3
# 3      Ontario  Apr 2005          100.9              100.9           100.7
# 4      Ontario  May 2005          101.3              101.3           100.9
# ...        ...       ...            ...                ...             ...
# 4555  Manitoba  Aug 2023          285.3              296.3           286.1
# 4556  Manitoba  Sep 2023          285.7              296.4           285.3
# 4557  Manitoba  Oct 2023          285.1              295.0           285.1
# 4558  Manitoba  Nov 2023          282.4              292.5           283.1
# 4559  Manitoba  Dec 2023          283.4              292.8           281.6
#
# ...

# %%
#Display second dataframe
covid_case_df
# Out:
#       reporting_year  Province_ID                Province  \
# 0               2020           59        British Columbia
# 1               2020           48                 Alberta
# 2               2020           47            Saskatchewan
# 3               2020           46                Manitoba
# 4               2020           35                 Ontario
# ...              ...          ...                     ...
# 3130            2024           60                   Yukon
# 3131            2024           61   Northwest Territories
# 3132            2024           62                 Nunavut
# 3133            2024           99  Repatriated travellers
# 3134            2024            1                  Canada
#
#                 Province_French        date  reporting_week  update  \
# 0          Colombie-Britannique  2020-02-01               5     1.0
# 1                       Alberta  2020-02-01               5     1.0
# ...

# %%
covid_case_df = covid_case_df.rename(columns={"reporting_year":"Year", "totalcases":"Total Cases"})
covid_case_df
# Out:
#       Year  Province_ID                Province            Province_French  \
# 0     2020           59        British Columbia       Colombie-Britannique
# 1     2020           48                 Alberta                    Alberta
# 2     2020           47            Saskatchewan               Saskatchewan
# 3     2020           46                Manitoba                   Manitoba
# 4     2020           35                 Ontario                    Ontario
# ...    ...          ...                     ...                        ...
# 3130  2024           60                   Yukon                      Yukon
# 3131  2024           61   Northwest Territories  Territoires du Nord-Ouest
# 3132  2024           62                 Nunavut                    Nunavut
# 3133  2024           99  Repatriated travellers        Voyageurs rapatriés
# 3134  2024            1                  Canada                     Canada
#
# ...

# %%
# #Combine data into one dataframe
covid_realestate_df = pd.merge(Real_estate_df,covid_case_df, how = "outer", on = ["Year"])
covid_realestate_df
# Out:
#        Province_x      Date  Composite HPI  Single Family HPI  One Storey HPI  \
# 0         Ontario  Jan 2005          100.0              100.0           100.0
# 1         Ontario  Feb 2005          100.2              100.2           100.2
# 2         Ontario  Mar 2005          100.6              100.6           100.3
# 3         Ontario  Apr 2005          100.9              100.9           100.7
# 4         Ontario  May 2005          101.3              101.3           100.9
# ...           ...       ...            ...                ...             ...
# 741655        NaN       NaN            NaN                NaN             NaN
# 741656        NaN       NaN            NaN                NaN             NaN
# 741657        NaN       NaN            NaN                NaN             NaN
# 741658        NaN       NaN            NaN                NaN             NaN
# 741659        NaN       NaN            NaN                NaN             NaN
#
# ...

# %%
covid_realestate_df = covid_realestate_df.rename(columns={"Province_x":"Province"})
covid_realestate_df
# Out:
#        Province      Date  Composite HPI  Single Family HPI  One Storey HPI  \
# 0       Ontario  Jan 2005          100.0              100.0           100.0
# 1       Ontario  Feb 2005          100.2              100.2           100.2
# 2       Ontario  Mar 2005          100.6              100.6           100.3
# 3       Ontario  Apr 2005          100.9              100.9           100.7
# 4       Ontario  May 2005          101.3              101.3           100.9
# ...         ...       ...            ...                ...             ...
# 741655      NaN       NaN            NaN                NaN             NaN
# 741656      NaN       NaN            NaN                NaN             NaN
# 741657      NaN       NaN            NaN                NaN             NaN
# 741658      NaN       NaN            NaN                NaN             NaN
# 741659      NaN       NaN            NaN                NaN             NaN
#
# ...

# %%
covid_realestate_df.dropna
# Out:
# <bound method DataFrame.dropna of        Province      Date  Composite HPI  Single Family HPI  One Storey HPI  \
# 0       Ontario  Jan 2005          100.0              100.0           100.0
# 1       Ontario  Feb 2005          100.2              100.2           100.2
# 2       Ontario  Mar 2005          100.6              100.6           100.3
# 3       Ontario  Apr 2005          100.9              100.9           100.7
# 4       Ontario  May 2005          101.3              101.3           100.9
# ...         ...       ...            ...                ...             ...
# 741655      NaN       NaN            NaN                NaN             NaN
# 741656      NaN       NaN            NaN                NaN             NaN
# 741657      NaN       NaN            NaN                NaN             NaN
# 741658      NaN       NaN            NaN                NaN             NaN
# 741659      NaN       NaN            NaN                NaN             NaN
#
# ...

# %%
homeprices_df= covid_realestate_df.groupby(["Province","Year"])

homeprices_df= pd.DataFrame(homeprices_df[['Single Family House','One Storey House',
                                           'Townhouse House','Apartment House','Total Cases']].median())

homeprices_df
# Out:
#                  Single Family House  One Storey House  Townhouse House  \
# Province   Year
# Aggregrate 2005             266700.0          213400.0         206400.0
#            2006             302450.0          246250.0         240200.0
#            2007             335900.0          278950.0         271100.0
#            2008             343200.0          284400.0         281100.0
#            2009             328100.0          268400.0         265750.0
# ...                              ...               ...              ...
# Vancouver  2019             689550.0          641550.0         496300.0
#            2020             758650.0          704750.0         535300.0
#            2021             974000.0          907150.0         634250.0
#            2022            1118050.0         1022250.0         743350.0
#            2023            1010050.0          935700.0         711650.0
#
#                  Apartment House  Total Cases
# Province   Year
# ...

# %%
# Real_estate_df[["Single Family House", "One Storey House", "Townhouse House",
#                     "Apartment House"]]=Real_estate_df.astype(float)
# Real_estate_df

# %%
#Determine the median of each year
Real_estate_df= Real_estate_df.groupby(["Province"])
Real_estate_df= pd.DataFrame(Real_estate_df[["Single Family House", "One Storey House", "Townhouse House",
                    "Apartment House"]].median())

Real_estate_df
# Out:
#                            Single Family House  One Storey House  \
# Province
# Aggregrate                            434100.0          334400.0
# Alberta                               396900.0          349850.0
# Manitoba                              253750.0          242800.0
# Newfoundland and Labrador             245250.0          222250.0
# Ontario                               331300.0          306400.0
# Saskatchewan                          305550.0          278250.0
# Vancouver                             565650.0          498000.0
#
#                            Townhouse House  Apartment House
# Province
# Aggregrate                        321900.0         272800.0
# Alberta                           247150.0         217700.0
# Manitoba                          235750.0         197450.0
# Newfoundland and Labrador         244100.0         195400.0
# Ontario                           250250.0         220700.0
# Saskatchewan                      258250.0         205100.0
# ...

# %%
import matplotlib.pyplot as plt

# Sample data
Province= ['Newfoundland and Labrador', 'Ontario', 'Vancouver(BC)']
Single_Family_House = [245250.0 ,331300.0 , 565650.0]

# Create bar plot
plt.bar(Province,Single_Family_House )

# Add labels and title
plt.xlabel('Province')
plt.ylabel('Values')
plt.title('Median of Single house Price in different provinces ')

# Display the plot
plt.show()

# %%
# Plotting Prime rate vs Year
plt.plot(covid_realestate_df["Year"], covid_realestate_df["Single Family House"], marker = "o", color = "b", linewidth = "0.5")
plt.plot(covid_realestate_df["Year"], covid_realestate_df["Apartment House"], marker = "o", color = "r", linewidth = "0.5")
plt.xlabel("Year")
plt.ylabel("Price of Single Family House%")
plt.title("Price of Single Family House from (2005-2023)")
plt.tight_layout()
plt.savefig("Output_data/Price of Single Family House from (2005-2023).png")
plt.show()

# %%
# Plotting ()homeprices_df(.iloc[:,0],filtered_groups_df.iloc[:,2])
            
# ["Year"], covid_realestate_df["Total Cases"], marker = "o", color = "b", linewidth = "0.5")
# plt.plot(covid_realestate_df["Year"], covid_realestate_df["Newdoundland and Labrador"], marker = "o", color = "r", linewidth = "0.5")
plt.xlabel("Year")
plt.ylabel("Total Cases")
plt.title("covid case in years")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    "Province": ["British Columbia", "Newfoundland and Labrador", "Ontario"],
    "2020": [3125.5, 262.0, 37231.5],
    "2021": [147605.0, 1385.5, 545532.0],
    "2022": [375357.0, 47773.0, 1336059.0],
    "2023": [403075.5, 56317.0, 1626254.0],
    "2024": [414863.5, 57801.0, 1700623.5]
}

df = pd.DataFrame(data)

# Transpose the DataFrame so that provinces become rows and years become columns
df = df.set_index("Province").transpose()

# Plot
plt.figure(figsize=(12, 6))
df.plot(kind='bar', stacked=True)
plt.title('Total Cases OF Covid by Province and Year')
plt.xlabel('Year')
plt.ylabel('Total Cases')
plt.xticks(rotation=45)
plt.legend(title='Province', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
